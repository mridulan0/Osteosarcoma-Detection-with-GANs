# %%
# !git clone https://github.com/NVlabs/stylegan2.git
# Out:
# Cloning into 'stylegan2'...
# remote: Enumerating objects: 138, done.
# remote: Counting objects: 100% (11/11), done.
# remote: Compressing objects: 100% (7/7), done.
# remote: Total 138 (delta 4), reused 10 (delta 4), pack-reused 127
# Receiving objects: 100% (138/138), 599.47 KiB | 17.63 MiB/s, done.
# Resolving deltas: 100% (62/62), done.

# %%
# %tensorflow_version 1.x
import tensorflow
print(tensorflow.__version__)
# Out:
# TensorFlow 1.x selected.
# 1.15.2

# %% [markdown]
# viable

# %%
# !python /content/stylegan2/run_generator.py generate-images --network=/content/viablenetwork-snapshot-004766.pkl --seeds=1-4820 --truncation-psi=0.8

# %%
# !tar cvf ViableGAN.tar /content/results/00010-generate-images

# %% [markdown]
# non tumor

# %%
# !python /content/stylegan2/run_generator.py generate-images --network=/content/network-snapshot-005005.pkl --seeds=1-4820 --truncation-psi=0.8
# Out:
# Local submit - run_dir: results/00000-generate-images
# dnnlib: Running run_generator.generate_images() on localhost...
# Loading networks from "/content/network-snapshot-005005.pkl"...
# Generating image for seed 1 (0/4820) ...
# Generating image for seed 2 (1/4820) ...
# Generating image for seed 3 (2/4820) ...
# Generating image for seed 4 (3/4820) ...
# Generating image for seed 5 (4/4820) ...
# Generating image for seed 6 (5/4820) ...
# Generating image for seed 7 (6/4820) ...
# Generating image for seed 8 (7/4820) ...
# Generating image for seed 9 (8/4820) ...
# Generating image for seed 10 (9/4820) ...
# Generating image for seed 11 (10/4820) ...
# Generating image for seed 12 (11/4820) ...
# Generating image for seed 13 (12/4820) ...
# Generating image for seed 14 (13/4820) ...
# Generating image for seed 15 (14/4820) ...
# Generating image for seed 16 (15/4820) ...
# Generating image for seed 17 (16/4820) ...
# Generating image for seed 18 (17/4820) ...
# ...

# %%
# !tar cvf NonTumorGAN.tar /content/results/00000-generate-images
# Out:
# tar: Removing leading `/' from member names
# /content/results/00000-generate-images/
# /content/results/00000-generate-images/seed1829.png
# /content/results/00000-generate-images/seed0725.png
# /content/results/00000-generate-images/seed4191.png
# /content/results/00000-generate-images/seed1258.png
# /content/results/00000-generate-images/seed3387.png
# /content/results/00000-generate-images/seed1930.png
# /content/results/00000-generate-images/seed1737.png
# /content/results/00000-generate-images/seed0699.png
# /content/results/00000-generate-images/seed2215.png
# /content/results/00000-generate-images/seed1906.png
# /content/results/00000-generate-images/seed0525.png
# /content/results/00000-generate-images/seed4452.png
# /content/results/00000-generate-images/seed2840.png
# /content/results/00000-generate-images/seed3215.png
# /content/results/00000-generate-images/seed2133.png
# /content/results/00000-generate-images/seed0534.png
# ...

# %% [markdown]
# non viable tumor

# %%
# !python /content/stylegan2/run_generator.py generate-images --network=/content/network-snapshot-005005.pkl --seeds=1-4820 --truncation-psi=0.8
# Out:
# Local submit - run_dir: results/00001-generate-images
# dnnlib: Running run_generator.generate_images() on localhost...
# Loading networks from "/content/network-snapshot-005005.pkl"...
# Generating image for seed 1 (0/4820) ...
# Generating image for seed 2 (1/4820) ...
# Generating image for seed 3 (2/4820) ...
# Generating image for seed 4 (3/4820) ...
# Generating image for seed 5 (4/4820) ...
# Generating image for seed 6 (5/4820) ...
# Generating image for seed 7 (6/4820) ...
# Generating image for seed 8 (7/4820) ...
# Generating image for seed 9 (8/4820) ...
# Generating image for seed 10 (9/4820) ...
# Generating image for seed 11 (10/4820) ...
# Generating image for seed 12 (11/4820) ...
# Generating image for seed 13 (12/4820) ...
# Generating image for seed 14 (13/4820) ...
# Generating image for seed 15 (14/4820) ...
# Generating image for seed 16 (15/4820) ...
# Generating image for seed 17 (16/4820) ...
# Generating image for seed 18 (17/4820) ...
# ...

# %%
# !tar cvf NonViableGAN.tar /content/results/00001-generate-images
# Out:
# tar: Removing leading `/' from member names
# /content/results/00001-generate-images/
# /content/results/00001-generate-images/seed1829.png
# /content/results/00001-generate-images/seed0725.png
# /content/results/00001-generate-images/seed4191.png
# /content/results/00001-generate-images/seed1258.png
# /content/results/00001-generate-images/seed3387.png
# /content/results/00001-generate-images/seed1930.png
# /content/results/00001-generate-images/seed1737.png
# /content/results/00001-generate-images/seed0699.png
# /content/results/00001-generate-images/seed2215.png
# /content/results/00001-generate-images/seed1906.png
# /content/results/00001-generate-images/seed0525.png
# /content/results/00001-generate-images/seed4452.png
# /content/results/00001-generate-images/seed2840.png
# /content/results/00001-generate-images/seed3215.png
# /content/results/00001-generate-images/seed2133.png
# /content/results/00001-generate-images/seed0534.png
# ...
